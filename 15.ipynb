# %% [markdown]
# Computer Vision with Python, OpenCV, Pytorch

# %% [markdown]
# Using Scipy

# %%
from PIL import Image
from scipy import linalg, ndimage
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.array([[2,1],[3,2]])
B = np.array([5,7])

x = linalg.solve(A, B)
print(x)
# Out:
# [ 3. -1.]

# %%
from scipy import integrate

def my_function(x):
    return x**2

integral = integrate.quad(my_function,0,1)
print(integral)
# Out:
# (0.3333333333333333, 3.700743415417188e-15)

# %%
A = np.array([[2,1],[3,2]])
evals, evecs = linalg.eig(A)
print("Value: ", evals)
print("Vector value: ", evecs)
# Out:
# Value:  [3.73205081+0.j 0.26794919+0.j]
# Vector value:  [[ 0.5       -0.5      ]
#  [ 0.8660254  0.8660254]]

# %%
image_path = '/Users/dandev947366/Desktop/Projects-github/computer-vision/computer-vision/img/01/1.JPG'

# Open the image using PIL and convert to grayscale
image = Image.open(image_path)
gray_image = image.convert('L')

# Convert the grayscale image to a NumPy array for processing
image_a = np.array(gray_image)

# Apply Gaussian blur with different sigma values
blurred_image_a = ndimage.gaussian_filter(image_a, sigma=0.5)
blurred_image_b = ndimage.gaussian_filter(image_a, sigma=1)
blurred_image_c = ndimage.gaussian_filter(image_a, sigma=3)

# Plotting the images using Matplotlib
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.imshow(gray_image, cmap='gray')
plt.title('Original Image')

plt.subplot(2, 2, 2)
plt.imshow(blurred_image_a, cmap='gray')
plt.title('Blurred (Sigma = 0.5)')

plt.subplot(2, 2, 3)
plt.imshow(blurred_image_b, cmap='gray')
plt.title('Blurred (Sigma = 1)')

plt.subplot(2, 2, 4)
plt.imshow(blurred_image_c, cmap='gray')
plt.title('Blurred (Sigma = 3)')

plt.tight_layout()
plt.show()
