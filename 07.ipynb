# %% [markdown]
# Computer Vision with Python, OpenCV, Pytorch, Matplotlib

# %% [markdown]
# Using Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
#image file path
my_img = '/Users/dandev947366/Desktop/Projects-github/computer-vision/computer-vision/img/01/1.jpg'
img = Image.open(my_img)

# %%
plt.imshow(img)

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16 ,20, 30, 25]
plt.plot(x,y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16 ,20, 30, 25]
plt.plot(x,y, color='red')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16 ,20, 30, 25]
plt.plot(x,y)
plt.title("Example")
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16 ,20, 30, 25]
plt.plot(x,y)
plt.title("Example")
plt.axis('off')
plt.show()

# %%
# Draw on img
im = Image.open(my_img)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]

plt.imshow(im)
plt.plot(x,y, 'bo--')
