# %% [markdown]
# Computer Vision with Python, OpenCV, Pytorch

# %% [markdown]
# Crop region from images

# %%
from PIL import Image
from imgtools import * 
from IPython.display import display # display images

# %%
#image file path
my_img_path = '/Users/dandev947366/Desktop/Projects-github/computer-vision/computer-vision/img/01/1.jpg'

# %%
img = load_image(my_img_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>

# %%
# crop image
region = (90,60, 175, 175)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=85x115>

# %%
# navigate position to paste img
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x332>
